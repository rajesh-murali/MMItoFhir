# %%
#!/usr/bin/env python
# coding: utf-8

"""
Reads MMI Pharmindex CSV files from the directory specified by the /datadir_mmi/
variable and writes corresponding FHIR Medication resources as json files 
(see https://simplifier.net/guide/MedizininformatikInitiative-ModulMedikation-
ImplementationGuide/Medication-duplicate-2) to the directory specified by the
/resultsdir/ variable.
"""

#  use logging module

from collections import defaultdict
from itertools import tee
import json
import os

import pandas as pd

# %%
import os

path = os.getcwd()

# %%
path
# Out:
# '/content'

# %%
datadir = path +'/data/'

# %%
datadir
# Out:
# '/content/data/'

# %%
datadir_mmi = f'{datadir}20200815MAIN/'
# Out:
# '/content/data/20200815MAIN/'

# %%
#datadir = './data/'
#datadir_mmi = f'{datadir}20200815MAIN/'
resultsdir =  f'{datadir}results/'

edqm_mapping_filename = 'EDQM-Standard-Terms_MMI-Mapping.csv'
edqm_mapping_encoding = 'windows-1252'
target_encoding = 'utf-8'
edqm_rename_columns = {
    'MAP_EDQM-Code': 'code',
    'MAP_EDQM-Name_DE': 'display',
}

filename_out = lambda pzn: f"{resultsdir}{pzn}.json"

extension = 'CSV'

column_separator = ';'

column_name_suffix_separator = '_'

id_ = 'ID'

clinicalpackage_name = 'CLINICALPACKAGE'
package_name = 'PACKAGE'
product_name = 'PRODUCT'
item_name = 'ITEM'
item_atc_name = 'ITEM_ATC'
item_compositionelement_name = 'ITEM_COMPOSITIONELEMENT'
compositionelement_name = 'COMPOSITIONELEMENT'
compositionelementequi_name = 'COMPOSITIONELEMENTEQUI'
molecule_name = 'MOLECULE'

catalogentry_name = 'CATALOGENTRY'

joins = (
    (
        package_name,
        product_name,
        item_name,        
        item_compositionelement_name,
        compositionelement_name,
        compositionelementequi_name,
        molecule_name,
    ),
    (
        item_name,
        item_atc_name,
    ),    
)

joins_clinical = (
    (
        clinicalpackage_name,
        product_name,
        item_name,        
        item_compositionelement_name,
        compositionelement_name,
        compositionelementequi_name,
        molecule_name,
    ),
    (
        item_name,
        item_atc_name,
    ),    
)

joins_active = tuple(
    tuple(
        table_name for table_name in join if table_name != compositionelementequi_name
    ) for join in joins
)

table_names = set(
    table_name for join in joins for table_name in join
)
table_names.add(catalogentry_name)
table_names.add(compositionelementequi_name)

def read(
    package_name,
    datadir=datadir_mmi,
    extension=extension,
    column_separator=column_separator,
):
    return pd.read_csv(
        f'{datadir}{package_name}.{extension}',
        sep=column_separator,
        dtype={
            # 
        },
    )

# source: https://docs.python.org/3/library/itertools.html
def pairwise(iterable):
    "s -> (s0,s1), (s1,s2), (s2, s3), ..."
    a, b = tee(iterable)
    next(b, None)
    return zip(a, b)

def replace_comma_with_dot(x):
    if type(x) == float:
        return str(x)
    else:
        return x.replace(',', '.')

# source (resource example): https://simplifier.net/guide/MedizininformatikInitiative-ModulMedikation-ImplementationGuide/Medication-duplicate-2
def medication_resource(
    id_,

    pzn_code,
    pzn_display,

    atc_code,
    atc_display,

    edqm_code,
    edqm_display,
):
    return {
        "resourceType": "Medication",
        "id": f"{id_}",
        "meta": {
            "profile":  [
                #"https://www.medizininformatik-initiative.de/fhir/core/modul-medikation/StructureDefinition/Medication"
                #"WHO ATC not included"
                # "under ingredient element ASK and CAS from MMI Pharm index are included. UNII and Snomed CT are not included because i dont have their source"
                #     "Unique ingredient identifier not included http://fdasis.nlm.nih.gov"
                #      "Snomed CT: http://snomed.info/sct "
            ]
        },
        "code": {
            "coding":  [
                {
                    "system": "http://fhir.de/CodeSystem/ifa/pzn",
                    "code": f"{pzn_code}", 
                    "display": f"{pzn_display}"
                },
                {
                    "system": "http://fhir.de/CodeSystem/bfarm/atc",
                    "code": f"{atc_code}",
                    "display": f"{atc_display}"
                }
            ]
        },
        "status": "active",
        "form": {
            "coding":  [
                {
                    "system": "http://standardterms.edqm.eu",
                    "code": f"{edqm_code}",
                    "display": f"{edqm_display}"
                }
            ]
        },
        "ingredient":  [
        ]
    }

def medication_item_codeable_concept(
    ask_code,
    ask_display,
    
    cas_code,
    cas_display,
):    
        return {
            "coding":  [
                {
                    "system": "http://fhir.de/CodeSystem/ask",
                    "code": f"{ask_code}",
                    "display": f"{ask_display}"
                },
                {
                    "system": "urn:oid:2.16.840.1.113883.6.61",
                    "code": f"{cas_code}",
                    "display": f"{cas_display}"
                }
            ]
        }

def medication_strength(
    strength_numer_value,
    strength_numer_system,
    strength_numer_code,
    strength_numer_unit,
    
    strength_denom_value,
    strength_denom_system,
    strength_denom_code,
    strength_denom_unit,
):            
    return {
        "numerator": {
            "value": strength_numer_value,
            "system": f"{strength_numer_system}",
            "code": f"{strength_numer_code}",
            "unit": f"{strength_numer_unit}"
        },
        "denominator": {
            "value": strength_denom_value,
            "system": f"{strength_denom_system}",
            "code": f"{strength_denom_code}",
            "unit": f"{strength_denom_unit}"
        }
    }

def medication_ingredient_active(
    molecule_id,    
    
    ask_code,
    ask_display,

    cas_code,
    cas_display,

    strength_numer_value,
    strength_numer_code,
    strength_numer_system,
    strength_numer_unit,

    strength_denom_value,
    strength_denom_system,
    strength_denom_code,
    strength_denom_unit,
):
    return {
        "id": f"{molecule_id}",
        "extension": [
            {
                "url": "https://www.medizininformatik-initiative.de/fhir/core/modul-medikation/StructureDefinition/wirkstofftyp",
                "valueCoding": {
                    "system": "https://www.medizininformatik-initiative.de/fhir/core/modul-medikation/CodeSystem/wirkstofftyp",
                    "code": "PIN",
                    "display": "precise ingredient"
                }
            }
        ],
        
        "isActive": True,
        
        "itemCodeableConcept": medication_item_codeable_concept(
            ask_code,
            ask_display,
            
            cas_code,
            cas_display,
        ),
        
        "strength": medication_strength(
            strength_numer_value,
            strength_numer_system,
            strength_numer_code,
            strength_numer_unit,
            strength_denom_value,
            strength_denom_system,
            strength_denom_code,
            strength_denom_unit,
        ),

    }

def medication_ingredient_equi(
    molecule_id,
    active_molecule_id,
    
    ask_code,
    ask_display,

    cas_code,
    cas_display,

    strength_numer_value,
    strength_numer_code,
    strength_numer_system,
    strength_numer_unit,

    strength_denom_value,
    strength_denom_system,
    strength_denom_code,
    strength_denom_unit,
):
    return {
        "id": f"{molecule_id}",
        "extension": [
            { 
                "extension": [
                    {
                        "url": "elementUri",
                        "valueUri": f"#{active_molecule_id}"
                    }
                ],
                "url": "https://www.medizininformatik-initiative.de/fhir/core/modul-medikation/StructureDefinition/wirkstoffrelation"
            },
            {
                "url": "https://www.medizininformatik-initiative.de/fhir/core/modul-medikation/StructureDefinition/wirkstofftyp",
                "valueCoding": {
                    "system": "https://www.medizininformatik-initiative.de/fhir/core/modul-medikation/CodeSystem/wirkstofftyp",
                    "code": "IN",
                    "display": "ingredient"
                }
            },
        ],
        
        "itemCodeableConcept": medication_item_codeable_concept(
            ask_code,
            ask_display,
            
            cas_code,
            cas_display,
        ),
        
        "strength": medication_strength(
            strength_numer_value,
            strength_numer_system,
            strength_numer_code,
            strength_numer_unit,
            
            strength_denom_value,
            strength_denom_system,
            strength_denom_code,
            strength_denom_unit,
        ),
    }

def filter_list(f, xs: list):
    res = []
    for x in xs:
        if type(x) is list:
            res.append(filter_list(f, x))
        elif type(x) is dict:
            res.append(filter_dict(f, x))
        elif f(x):
            res.append(x)
        else:
            pass
    return res

def filter_dict(f, d: dict):
    res = {}
    for k,v in d.items():
        if type(v) is list:
            res[k] = filter_list(f, v)
        elif type(v) is dict:
            res[k] = filter_dict(f, v)
        elif f(v):
            res[k] = v
        else:
            pass
    return res

def filter_missing(d: dict):
    return filter_dict(
        lambda x: not (pd.isna(x) or x in ('None', 'nan')), d
    )

d = {
    'A0k': {
        'A01k': 'A01v',
        'A02k': 'A02v',
        'A03k': None,
    },
    'A1k': 'A1v',
    'A2k': float('nan'),
}
assert filter_missing(d) == {'A0k': {'A01k': 'A01v', 'A02k': 'A02v'}, 'A1k': 'A1v'}

# %%
pwd
# Out:
# '/content'

# %%
with open(f'{datadir}{edqm_mapping_filename}', encoding=edqm_mapping_encoding) as f:
    edqm = pd.read_csv(f, sep=';')
    
edqm.rename(
    columns=edqm_rename_columns,
    inplace=True,
)

def decode(text, source_encoding=edqm_mapping_encoding, target_encoding=target_encoding):
    if type(text) == float: return text    
    try:
        return text.encode(source_encoding).decode(target_encoding)
    except:
        # TODO make sure `text` is already encoded with `target_encoding`
        # in our use case, `text´ is not consistently encoded – this is an ad-hoc workaround
        return text

edqm.display = edqm.display.apply(
    decode
)

# %%
tables = {
    table_name: read(
        table_name
    ).rename(
        columns={
            id_: table_name+id_
        }
    )
     for table_name in table_names
}
for table_name, table in tables.items():
    table.rename(
        columns=dict(zip(
            table.columns,
            (c if c.endswith(id_) else c+column_name_suffix_separator+table_name for c in table.columns),
        )),
        inplace=True,
    )
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (15,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (13,17,29,30) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (18) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
print(f'ACTIVE substances. Starting with table {joins_active[0][0]}.')
res_active = tables[joins_active[0][0]]
for join in joins_active:
    for table1_name,table2_name in pairwise(join):        
        table1_columns = tables[table1_name].columns
        table2_columns = tables[table2_name].columns
        table1_id = table1_name+id_
        if table1_id in table1_columns and table1_id in table2_columns:
            index = table1_id
        else:
            index = table2_name+id_        
        print(f'Joining {table2_name} using {index}', end=' ') 
        res_active = res_active.join(
            tables[table2_name].set_index(index),
            on=index,
        )
        print('done.')
print('All ACTIVE substance tables joined.')
# only consider active substances
res_active = res_active[res_active['MOLECULETYPECODE_COMPOSITIONELEMENT'] == 'A']
# Out:
# ACTIVE substances. Starting with table PACKAGE.
# Joining PRODUCT using PRODUCTID done.
# Joining ITEM using PRODUCTID done.
# Joining ITEM_COMPOSITIONELEMENT using ITEMID done.
# Joining COMPOSITIONELEMENT using COMPOSITIONELEMENTID done.
# Joining MOLECULE using MOLECULEID done.
# Joining ITEM_ATC using ITEMID done.
# All ACTIVE substance tables joined.

# %%
print(f'EQUIVALENT substances. Starting with table {joins[0][0]}.')
res = tables[joins[0][0]]
for join in joins:
    for table1_name,table2_name in pairwise(join):        
        table1_columns = tables[table1_name].columns
        table2_columns = tables[table2_name].columns
        table1_id = table1_name+id_
        if table1_id in table1_columns and table1_id in table2_columns:
            index = table1_id
        else:
            index = table2_name+id_        
        # use EQMOLECULEID to join COMPESITIONELEMENTEQUI with MOLECULE
        if index == 'MOLECULEID':
            assert table2_name == molecule_name
            print(f'Joining {table2_name} using (EQ){index}', end=' ') 
            res = res.join(
                tables[table2_name].set_index(index),
                on='EQMOLECULEID',
            )            
        else:
            print(f'Joining {table2_name} using {index}', end=' ') 
            res = res.join(
                tables[table2_name].set_index(index),
                on=index,
            )
        print('done.')
print('All EQUIVALENT substance tables joined.')

# only consider active substances (and their equivalents)
res = res[res['MOLECULETYPECODE_COMPOSITIONELEMENT'] == 'A']
# Out:
# EQUIVALENT substances. Starting with table PACKAGE.
# Joining PRODUCT using PRODUCTID done.
# Joining ITEM using PRODUCTID done.
# Joining ITEM_COMPOSITIONELEMENT using ITEMID done.
# Joining COMPOSITIONELEMENT using COMPOSITIONELEMENTID done.
# Joining COMPOSITIONELEMENTEQUI using COMPOSITIONELEMENTID done.
# Joining MOLECULE using (EQ)MOLECULEID done.
# Joining ITEM_ATC using ITEMID done.
# All EQUIVALENT substance tables joined.

# %%
pzns = [int(x) for x in res_active.PZN_PACKAGE.unique() if pd.notna(x)]
n = len(pzns)

assert n == len(set(pzns))

# %%
catalogentry = defaultdict(lambda: {
                'code': None,
                'display': None,
            })
for (index,row) in tables[catalogentry_name].iterrows():    
    catalogentry[row['CATALOGID'],row['CODE_CATALOGENTRY']] = {
        'code': row['CODE_CATALOGENTRY'],
        'display': row['NAME_CATALOGENTRY'],
    }

# %%
print('Building mapping PZN -> ACTIVE substance info', end=' ')
pzn_rows_active = {
    pzn: res_active[res_active.PZN_PACKAGE == pzn] for pzn in pzns
}
print('done.')
# Out:
# Building mapping PZN -> ACTIVE substance info done.

# %%
print('Building mapping PZN -> EQUIVALENT substance info', end=' ')
pzn_rows = {
    pzn: res[res.PZN_PACKAGE == pzn] for pzn in pzns
}
print('done.')
# Out:
# Building mapping PZN -> EQUIVALENT substance info done.

# %%
# 1
# Refactor loop 
for j,pzn in enumerate(pzns):
#for j,pzn in enumerate([
#    13978380, # example with more equivalent than active substances
#]):
    fhir = {}
    print("TEST", filename_out(pzn)) 
    fno = filename_out(pzn)
    if os.path.isfile(fno):
        continue
    else:
        print(f'{100*j/n:05.1f}% done\r', end='')
        
    rows_active = pzn_rows_active[pzn] 
    
    if not len(rows_active):
        continue
        
    rows = pzn_rows[pzn]
    
    #try:
    #    assert len(rows) <= len(rows_active)
    #except AssertionError:        
    #    print(f'ERROR for PZN {pzn}: more equivalent than active substances.')
    #    continue
        
    assert len(rows_active)
    
    # create resource with basic info
    
    row_active = rows_active.iloc[0] 
    
    atc_code = row_active['ATCCODE_ITEM_ATC']

    if pd.isna(atc_code):
        print(f'INFO  for PZN {pzn}: no ATC code – skipping..')
        continue

    catalogentry_row_atc = catalogentry[row_active['ATCCATALOGID'], atc_code]

    catalogentry_row_base_unit = catalogentry[
        row_active['BASEMOLECULEUNITCATALOGID'],
        row_active['BASEMOLECULEUNITCODE_ITEM'],
    ]

    catalogentry_row_pharmform = edqm[
        (edqm.CATALOGID == row_active['PHARMFORMCATALOGID']) &
        (edqm.CODE == float(row_active['PHARMFORMCODE_ITEM']))
    ]    
    
    catalogentry_row_pharmform_mmi = catalogentry[
        row_active['PHARMFORMCATALOGID'],        
        '{:03.0f}'.format(row_active['PHARMFORMCODE_ITEM']),        
    ]    
    
    if not len(catalogentry_row_pharmform):
        print(f"ERROR for PZN {pzn}: missing EDQM info. Package: `{row_active['NAME_PACKAGE']}`")
        continue
        
    try:
        catalogentry_row_pharmform_code = int(
            catalogentry_row_pharmform['code'].values[0]
        )
    except:
        assert pd.isna(catalogentry_row_pharmform['code'].values[0])
        catalogentry_row_pharmform_code = None
        print(
            f"ERROR for PZN {pzn}: missing EDQM info. Package: `{row_active['NAME_PACKAGE']}`. Mapping: `{catalogentry_row_pharmform['display'].values[0]}`. \
MMI: `{catalogentry_row_pharmform_mmi['display']}`."
        )

    fhir = filter_missing(medication_resource(
        id_=None,
        pzn_code=pzn,
        pzn_display=row_active['NAME_PACKAGE'],
        atc_code=catalogentry_row_atc['code'],
        atc_display=catalogentry_row_atc['display'],
        edqm_code=catalogentry_row_pharmform_code,
        edqm_display=catalogentry_row_pharmform['display'].values[0],
    ))
    
    # add active ingredients info
    
    for i in range(
        len(rows_active)
    ):
        row_active = rows_active.iloc[i]
        
        molecule_unit_code_active = row_active['MOLECULEUNITCODE_COMPOSITIONELEMENT']                
        catalogentry_row_unit_active = catalogentry[row_active['MOLECULEUNITCATALOGID'], molecule_unit_code_active]

        fhir['ingredient'].append(
            filter_missing(medication_ingredient_active(
                molecule_id=int(row_active['MOLECULEID']),
                ask_code=(row_active['ASKNUMBER_MOLECULE']),
                ask_display=(row_active['NAME_MOLECULE']),
                cas_code=(row_active['CASREGISTRATIONNUMBER_MOLECULE']),
                cas_display=(row_active['NAME_MOLECULE']),
                strength_numer_system='http://unitsofmeasure.org',
                strength_numer_value=float(replace_comma_with_dot(
                    row_active['MASSFROM_COMPOSITIONELEMENT']
                )),
                strength_numer_code=molecule_unit_code_active,
                strength_numer_unit=catalogentry_row_unit_active['display'],
                strength_denom_value=float(replace_comma_with_dot(row_active['BASECOUNT_ITEM'])),
                strength_denom_code=None if float(strength_denom_value) == 1 else row_active['BASEMOLECULEUNITCODE_ITEM'],
                strength_denom_system=None if pd.isna(strength_denom_code) else 'http://unitsofmeasure.org',                
                strength_denom_unit=None if float(strength_denom_value) == 1 else catalogentry_row_base_unit['display'],
        )))  
   
    # add equivalent ingredients info
        
    for i in range(    
        len(rows)
    ):        
        row = rows.iloc[i]
        
        #  check
        molecule_id = int(row['MOLECULEID'])
        eq_molecule_id = row['EQMOLECULEID']
        
        if pd.isna(eq_molecule_id):
            continue # no equivalent ingredient
        else:
            eq_molecule_id = int(eq_molecule_id)
            try:
                assert molecule_id != eq_molecule_id
            except:
                print(f"ERROR for PZN {pzn}: molecule_id and eq_molecule_id are the same. Package: `{row_active['NAME_PACKAGE']}` \
Active-molec.: `{row_active['NAME_MOLECULE']}`. Active–unit: `{catalogentry_row_unit_active['display']}`. Equivt-molec.: `{row['NAME_MOLECULE']}`. Equivt–unit. `{catalogentry_row_unit_equivt['display']}`.")
                continue
                
        molecule_unit_code_equivt = row['EQMOLECULEUNITCODE_COMPOSITIONELEMENTEQUI']
        catalogentry_row_unit_equivt = catalogentry[row['EQMOLECULEUNITCATALOGID'], molecule_unit_code_equivt]
        
        fhir['ingredient'].append(
        filter_missing(medication_ingredient_equi(
            molecule_id=eq_molecule_id,
            active_molecule_id=molecule_id,
            ask_code=row['ASKNUMBER_MOLECULE'],
            #ask_display=(name_molecule:=row['NAME_MOLECULE']),
            ask_display=row['NAME_MOLECULE'],
            cas_code=row['CASREGISTRATIONNUMBER_MOLECULE'],
            cas_display=(row['NAME_MOLECULE']),
            strength_numer_system='http://unitsofmeasure.org',
            strength_numer_value=float(replace_comma_with_dot(
                row['EQMASSFROM_COMPOSITIONELEMENTEQUI']
            )),
            strength_numer_code=molecule_unit_code_equivt,
            strength_numer_unit=catalogentry_row_unit_equivt['display'],
            strength_denom_value=float(replace_comma_with_dot(row['BASECOUNT_ITEM'])),
            strength_denom_code=None if float(strength_denom_value) == 1 else row['BASEMOLECULEUNITCODE_ITEM'],      
            strength_denom_system=None if pd.isna(strength_denom_code) else 'http://unitsofmeasure.org',                        
            strength_denom_unit=None if float(strength_denom_value) == 1 else catalogentry_row_base_unit['display'],
        )))
        
    if fhir:
        fhir_pzns = set(d['code'] for d in fhir['code']['coding'] if d['system'].endswith('pzn'))
        assert len(fhir_pzns) == 1
        assert fno.split('/')[-1].rstrip('.json') == str(pzn) == list(fhir_pzns)[0]
        with open(fno, 'w', encoding="utf-8") as f:
            json.dump(fhir, f, indent=4, ensure_ascii=False)
            del fhir
# Out:
# Die letzten 5000 Zeilen der Streamingausgabe wurden abgeschnitten.
# TEST /content/data/results/16042615.json
# TEST /content/data/results/14026983.json
# TEST /content/data/results/15882508.json
# TEST /content/data/results/15735144.json
# TEST /content/data/results/15874727.json
# TEST /content/data/results/13828166.json
# TEST /content/data/results/15741541.json
# TEST /content/data/results/15741469.json
# TEST /content/data/results/14330965.json
# TEST /content/data/results/15586098.json
# TEST /content/data/results/13828108.json
# TEST /content/data/results/15569355.json
# TEST /content/data/results/16042354.json
# TEST /content/data/results/9941313.json
# TEST /content/data/results/15896491.json
# TEST /content/data/results/14375063.json
# TEST /content/data/results/9941359.json
# TEST /content/data/results/16035259.json
# TEST /content/data/results/15741386.json
# TEST /content/data/results/16042609.json
# TEST /content/data/results/15586052.json
# TEST /content/data/results/15415698.json
# TEST /content/data/results/15434106.json
# TEST /content/data/results/15888706.json
# TEST /content/data/results/15741239.json
# TEST /content/data/results/15586075.json
# TEST /content/data/results/15896344.json
# TEST /content/data/results/15586023.json
# TEST /content/data/results/15562152.json
# TEST /content/data/results/15741825.json
# TEST /content/data/results/15741713.json
# TEST /content/data/results/13872374.json
# TEST /content/data/results/15888698.json
# TEST /content/data/results/16042584.json
# TEST /content/data/results/15637074.json
# TEST /content/data/results/16042466.json
# TEST /content/data/results/15869761.json
# TEST /content/data/results/14042580.json
# TEST /content/data/results/12548565.json
# TEST /content/data/results/14375005.json
# TEST /content/data/results/16129569.json
# TEST /content/data/results/16042437.json
# TEST /content/data/results/15568433.json
# TEST /content/data/results/12548588.json
# TEST /content/data/results/16127004.json
# TEST /content/data/results/15741251.json
# TEST /content/data/results/13828060.json
# TEST /content/data/results/15741452.json
# TEST /content/data/results/15741274.json
# TEST /content/data/results/16042590.json
# TEST /content/data/results/15741529.json
# TEST /content/data/results/15741742.json
# TEST /content/data/results/14001428.json
# TEST /content/data/results/15741759.json
# TEST /content/data/results/13872500.json
# TEST /content/data/results/15416203.json
# TEST /content/data/results/15628856.json
# TEST /content/data/results/15871396.json
# TEST /content/data/results/15578816.json
# TEST /content/data/results/14027014.json
# TEST /content/data/results/2055399.json
# TEST /content/data/results/16042489.json
# TEST /content/data/results/15815831.json
# TEST /content/data/results/15747058.json
# TEST /content/data/results/15579773.json
# TEST /content/data/results/16042532.json
# TEST /content/data/results/15563097.json
# TEST /content/data/results/15612453.json
# TEST /content/data/results/15621392.json
# TEST /content/data/results/15815854.json
# TEST /content/data/results/15815877.json
# TEST /content/data/results/15993900.json
# TEST /content/data/results/14232895.json
# TEST /content/data/results/16119967.json
# TEST /content/data/results/15426064.json
# TEST /content/data/results/16042472.json
# TEST /content/data/results/15732849.json
# ERROR for PZN 15732849: missing EDQM info. Package: `Suprefact Depot 9,45 mg Haemato Pharm 3-Monatsimplantat 2 Fertigspritzen N2`. Mapping: `nan`. MMI: `Implantat, subcutan`.
# TEST /content/data/results/15741179.json
# TEST /content/data/results/15888505.json
# TEST /content/data/results/14370605.json
# TEST /content/data/results/15607535.json
# TEST /content/data/results/14232872.json
# TEST /content/data/results/15741357.json
# TEST /content/data/results/15432886.json
# TEST /content/data/results/16036773.json
# TEST /content/data/results/13828054.json
# TEST /content/data/results/15735121.json
# TEST /content/data/results/15815860.json
# TEST /content/data/results/13891437.json
# TEST /content/data/results/15640490.json
# TEST /content/data/results/15619722.json
# TEST /content/data/results/13856688.json
# TEST /content/data/results/13828114.json
# TEST /content/data/results/15735109.json
# TEST /content/data/results/15578851.json
# TEST /content/data/results/15415681.json
# TEST /content/data/results/15639392.json
# TEST /content/data/results/15634130.json
# TEST /content/data/results/15741771.json
# TEST /content/data/results/15586081.json
# TEST /content/data/results/15870528.json
# TEST /content/data/results/15612447.json
# TEST /content/data/results/14331031.json
# TEST /content/data/results/15640573.json
# TEST /content/data/results/15741328.json
# TEST /content/data/results/16120002.json
# TEST /content/data/results/13891443.json
# TEST /content/data/results/14853290.json
# TEST /content/data/results/14330994.json
# TEST /content/data/results/16042408.json
# TEST /content/data/results/15741392.json
# TEST /content/data/results/12607316.json
# TEST /content/data/results/14375011.json
# TEST /content/data/results/15637080.json
# TEST /content/data/results/15416249.json
# TEST /content/data/results/16042561.json
# TEST /content/data/results/15741593.json
# TEST /content/data/results/15569326.json
# TEST /content/data/results/15741340.json
# TEST /content/data/results/15741280.json
# TEST /content/data/results/15416189.json
# TEST /content/data/results/15741624.json
# TEST /content/data/results/16042383.json
# TEST /content/data/results/15741475.json
# TEST /content/data/results/14032529.json
# TEST /content/data/results/15741794.json
# TEST /content/data/results/15741682.json
# TEST /content/data/results/13853483.json
# TEST /content/data/results/16002461.json
# TEST /content/data/results/15637068.json
# TEST /content/data/results/15896657.json
# TEST /content/data/results/15619030.json
# TEST /content/data/results/15895617.json
# TEST /content/data/results/15637051.json
# TEST /content/data/results/15612476.json
# TEST /content/data/results/15741498.json
# TEST /content/data/results/14331019.json
# TEST /content/data/results/16042555.json
# TEST /content/data/results/15437010.json
# TEST /content/data/results/16000864.json
# TEST /content/data/results/15741311.json
# TEST /content/data/results/16120025.json
# TEST /content/data/results/2055382.json
# TEST /content/data/results/15391733.json
# TEST /content/data/results/14331002.json
# TEST /content/data/results/14327880.json
# TEST /content/data/results/15861340.json
# TEST /content/data/results/15741185.json
# TEST /content/data/results/15782899.json
# TEST /content/data/results/15656189.json
# TEST /content/data/results/15563105.json
# TEST /content/data/results/16042420.json
# TEST /content/data/results/15741535.json
# TEST /content/data/results/15741765.json
# TEST /content/data/results/15815883.json
# TEST /content/data/results/14227635.json
# TEST /content/data/results/15563080.json
# TEST /content/data/results/15741819.json
# TEST /content/data/results/15741618.json
# TEST /content/data/results/15579158.json
# TEST /content/data/results/15562146.json
# TEST /content/data/results/15563068.json
# TEST /content/data/results/13872457.json
# TEST /content/data/results/15786584.json
# TEST /content/data/results/16042443.json
# TEST /content/data/results/15585986.json
# TEST /content/data/results/14210681.json
# TEST /content/data/results/15735090.json
# TEST /content/data/results/13711814.json
# TEST /content/data/results/16042495.json
# TEST /content/data/results/15996560.json
# TEST /content/data/results/15608322.json
# TEST /content/data/results/13856702.json
# TEST /content/data/results/15634147.json
# TEST /content/data/results/15745183.json
# TEST /content/data/results/15741268.json
# TEST /content/data/results/15375214.json
# TEST /content/data/results/15745622.json
# TEST /content/data/results/15232029.json
# TEST /content/data/results/15622411.json
# TEST /content/data/results/16121349.json
# TEST /content/data/results/14320524.json
# TEST /content/data/results/14349462.json
# TEST /content/data/results/16136084.json
# TEST /content/data/results/16121817.json
# TEST /content/data/results/14018570.json
# TEST /content/data/results/16121875.json
# TEST /content/data/results/15584509.json
# TEST /content/data/results/15387789.json
# TEST /content/data/results/16121438.json
# TEST /content/data/results/15568203.json
# TEST /content/data/results/14320501.json
# TEST /content/data/results/16128541.json
# TEST /content/data/results/16121705.json
# TEST /content/data/results/16121728.json
# TEST /content/data/results/15293373.json
# TEST /content/data/results/12653351.json
# TEST /content/data/results/15617249.json
# TEST /content/data/results/14446403.json
# TEST /content/data/results/16121651.json
# TEST /content/data/results/15619892.json
# TEST /content/data/results/15293410.json
# TEST /content/data/results/16121786.json
# TEST /content/data/results/15816262.json
# TEST /content/data/results/15577366.json
# TEST /content/data/results/14440754.json
# TEST /content/data/results/16121527.json
# TEST /content/data/results/16121303.json
# TEST /content/data/results/15205819.json
# TEST /content/data/results/15434158.json
# TEST /content/data/results/16121680.json
# TEST /content/data/results/15890324.json
# TEST /content/data/results/15584515.json
# TEST /content/data/results/14349479.json
# TEST /content/data/results/16127079.json
# TEST /content/data/results/15583935.json
# TEST /content/data/results/15743876.json
# TEST /content/data/results/15661026.json
# TEST /content/data/results/15584521.json
# TEST /content/data/results/16127263.json
# TEST /content/data/results/15744628.json
# TEST /content/data/results/15293396.json
# TEST /content/data/results/15888876.json
# TEST /content/data/results/15253534.json
# TEST /content/data/results/16128558.json
# TEST /content/data/results/15622397.json
# TEST /content/data/results/15205831.json
# TEST /content/data/results/15609132.json
# TEST /content/data/results/16035414.json
# TEST /content/data/results/15617278.json
# TEST /content/data/results/14243120.json
# TEST /content/data/results/15612648.json
# TEST /content/data/results/15744485.json
# TEST /content/data/results/16121622.json
# TEST /content/data/results/5395374.json
# TEST /content/data/results/15743853.json
# TEST /content/data/results/16121800.json
# TEST /content/data/results/15432923.json
# TEST /content/data/results/14320530.json
# TEST /content/data/results/16121326.json
# TEST /content/data/results/16121444.json
# TEST /content/data/results/15387795.json
# TEST /content/data/results/16121616.json
# TEST /content/data/results/14446426.json
# TEST /content/data/results/15584490.json
# TEST /content/data/results/14446389.json
# TEST /content/data/results/15434075.json
# TEST /content/data/results/14446343.json
# TEST /content/data/results/15896663.json
# TEST /content/data/results/15568249.json
# TEST /content/data/results/15884401.json
# TEST /content/data/results/16121473.json
# TEST /content/data/results/16121792.json
# TEST /content/data/results/15890330.json
# TEST /content/data/results/16121533.json
# TEST /content/data/results/14052348.json
# TEST /content/data/results/15433762.json
# TEST /content/data/results/16121467.json
# TEST /content/data/results/15745645.json
# TEST /content/data/results/15626142.json
# TEST /content/data/results/16144787.json
# TEST /content/data/results/16134458.json
# TEST /content/data/results/16121763.json
# TEST /content/data/results/14372277.json
# TEST /content/data/results/14052360.json
# TEST /content/data/results/16121510.json
# TEST /content/data/results/16121390.json
# TEST /content/data/results/15205825.json
# TEST /content/data/results/14446372.json
# TEST /content/data/results/14243686.json
# TEST /content/data/results/15609184.json
# TEST /content/data/results/16121697.json
# TEST /content/data/results/14440760.json
# TEST /content/data/results/15577343.json
# TEST /content/data/results/16128564.json
# TEST /content/data/results/16121585.json
# TEST /content/data/results/15205802.json
# TEST /content/data/results/15404298.json
# TEST /content/data/results/15816279.json
# TEST /content/data/results/15253557.json
# TEST /content/data/results/16144646.json
# TEST /content/data/results/15617261.json
# TEST /content/data/results/16121639.json
# TEST /content/data/results/16121415.json
# TEST /content/data/results/15816285.json
# TEST /content/data/results/14446449.json
# TEST /content/data/results/16132086.json
# TEST /content/data/results/12653368.json
# TEST /content/data/results/16121556.json
# TEST /content/data/results/12653374.json
# TEST /content/data/results/15586425.json
# TEST /content/data/results/15434164.json
# TEST /content/data/results/16121869.json
# TEST /content/data/results/15235163.json
# TEST /content/data/results/14238219.json
# TEST /content/data/results/14294577.json
# TEST /content/data/results/15816256.json
# TEST /content/data/results/16121740.json
# TEST /content/data/results/14039046.json
# TEST /content/data/results/15398385.json
# TEST /content/data/results/16121711.json
# TEST /content/data/results/16136078.json
# TEST /content/data/results/16121504.json
# TEST /content/data/results/16121562.json
# TEST /content/data/results/15784697.json
# TEST /content/data/results/14349516.json
# TEST /content/data/results/16121384.json
# TEST /content/data/results/15881555.json
# TEST /content/data/results/16121674.json
# TEST /content/data/results/15622405.json
# TEST /content/data/results/14243031.json
# TEST /content/data/results/14320518.json
# TEST /content/data/results/14140578.json
# TEST /content/data/results/14294608.json
# TEST /content/data/results/15784680.json
# TEST /content/data/results/16121378.json
# TEST /content/data/results/15890927.json
# TEST /content/data/results/16127085.json
# TEST /content/data/results/13503151.json
# TEST /content/data/results/15227407.json
# TEST /content/data/results/15784705.json
# TEST /content/data/results/15619900.json
# TEST /content/data/results/16121361.json
# TEST /content/data/results/15609190.json
# TEST /content/data/results/16121579.json
# TEST /content/data/results/16121734.json
# TEST /content/data/results/15584484.json
# TEST /content/data/results/15884418.json
# TEST /content/data/results/16121852.json
# TEST /content/data/results/15617284.json
# TEST /content/data/results/15586419.json
# TEST /content/data/results/15888847.json
# TEST /content/data/results/15579135.json
# TEST /content/data/results/15619886.json
# TEST /content/data/results/15486089.json
# TEST /content/data/results/16020387.json
# TEST /content/data/results/15888882.json
# TEST /content/data/results/16121450.json
# TEST /content/data/results/15884393.json
# TEST /content/data/results/15745237.json
# TEST /content/data/results/15619857.json
# TEST /content/data/results/15203654.json
# TEST /content/data/results/16132063.json
# TEST /content/data/results/15661032.json
# TEST /content/data/results/16134441.json
# TEST /content/data/results/15398391.json
# TEST /content/data/results/16121668.json
# TEST /content/data/results/14446395.json
# TEST /content/data/results/15820743.json
# TEST /content/data/results/16127062.json
# TEST /content/data/results/15612654.json
# TEST /content/data/results/14440725.json
# TEST /content/data/results/15227442.json
# TEST /content/data/results/16121421.json
# TEST /content/data/results/13509461.json
# ERROR for PZN 13509461: missing EDQM info. Package: `Mirena Abacus 52 mg 1 Intrauterinpessar mit Hormonabgabe N3`. Mapping: `nan`. MMI: `Intrauterinpessar`.
# TEST /content/data/results/15745639.json
# TEST /content/data/results/16127286.json
# TEST /content/data/results/15617232.json
# TEST /content/data/results/15433986.json
# TEST /content/data/results/15227436.json
# TEST /content/data/results/15612430.json
# TEST /content/data/results/16121757.json
# TEST /content/data/results/15612565.json
# TEST /content/data/results/16136061.json
# TEST /content/data/results/16121332.json
# TEST /content/data/results/15568232.json
# TEST /content/data/results/16121496.json
# TEST /content/data/results/15227413.json
# TEST /content/data/results/15619863.json
# TEST /content/data/results/14446432.json
# TEST /content/data/results/15784668.json
# TEST /content/data/results/14349491.json
# TEST /content/data/results/14446366.json
# TEST /content/data/results/16131856.json
# TEST /content/data/results/13868823.json
# TEST /content/data/results/14215017.json
# TEST /content/data/results/14035597.json
# TEST /content/data/results/15417289.json
# TEST /content/data/results/14027008.json
# TEST /content/data/results/15417303.json
# TEST /content/data/results/16127122.json
# TEST /content/data/results/16036951.json
# TEST /content/data/results/15620079.json
# TEST /content/data/results/15815110.json
# TEST /content/data/results/16086788.json
# TEST /content/data/results/16031356.json
# TEST /content/data/results/14215000.json
# TEST /content/data/results/16127205.json
# TEST /content/data/results/15864522.json
# TEST /content/data/results/16029968.json
# TEST /content/data/results/15609095.json
# TEST /content/data/results/15888675.json
# TEST /content/data/results/16036980.json
# TEST /content/data/results/10822393.json
# TEST /content/data/results/15297359.json
# TEST /content/data/results/16036945.json
# TEST /content/data/results/15877430.json
# TEST /content/data/results/14234428.json
# TEST /content/data/results/15993917.json
# TEST /content/data/results/15735291.json
# TEST /content/data/results/16127116.json
# TEST /content/data/results/12724370.json
# TEST /content/data/results/15817267.json
# TEST /content/data/results/15870184.json
# TEST /content/data/results/15568315.json
# TEST /content/data/results/15433911.json
# TEST /content/data/results/15864516.json
# TEST /content/data/results/15888818.json
# TEST /content/data/results/15746840.json
# TEST /content/data/results/15815127.json
# TEST /content/data/results/15817250.json
# TEST /content/data/results/15817675.json
# TEST /content/data/results/16029945.json
# TEST /content/data/results/15297342.json
# TEST /content/data/results/15996761.json
# TEST /content/data/results/15583912.json
# TEST /content/data/results/16127174.json
# TEST /content/data/results/15735285.json
# TEST /content/data/results/15423574.json
# TEST /content/data/results/14326946.json
# TEST /content/data/results/14405290.json
# TEST /content/data/results/16127168.json
# TEST /content/data/results/15619797.json
# TEST /content/data/results/15423605.json
# TEST /content/data/results/15612542.json
# TEST /content/data/results/15417326.json
# TEST /content/data/results/15612559.json
# TEST /content/data/results/15619805.json
# TEST /content/data/results/16146384.json
# TEST /content/data/results/15620056.json
# TEST /content/data/results/16085211.json
# TEST /content/data/results/16013499.json
# TEST /content/data/results/15626171.json
# TEST /content/data/results/15505295.json
# TEST /content/data/results/16131885.json
# TEST /content/data/results/15896752.json
# TEST /content/data/results/16133855.json
# TEST /content/data/results/16000893.json
# TEST /content/data/results/15657467.json
# TEST /content/data/results/15888801.json
# TEST /content/data/results/16127091.json
# TEST /content/data/results/16017847.json
# ERROR for PZN 16017847: missing EDQM info. Package: `Zoladex 10,8 mg 101 Carefarm Implant 1 Fertigspritze N1`. Mapping: `nan`. MMI: `Implantat, subcutan`.
# TEST /content/data/results/16131862.json
# TEST /content/data/results/16127240.json
# TEST /content/data/results/15612683.json
# TEST /content/data/results/16146378.json
# TEST /content/data/results/15888681.json
# TEST /content/data/results/16136204.json
# TEST /content/data/results/16131879.json
# TEST /content/data/results/15583906.json
# TEST /content/data/results/12724364.json
# TEST /content/data/results/11715328.json
# TEST /content/data/results/16031379.json
# TEST /content/data/results/15996778.json
# TEST /content/data/results/15996726.json
# TEST /content/data/results/16013571.json
# TEST /content/data/results/15817244.json
# TEST /content/data/results/16036974.json
# TEST /content/data/results/14063837.json
# TEST /content/data/results/15659756.json
# TEST /content/data/results/15896516.json
# TEST /content/data/results/14398182.json
# TEST /content/data/results/15656309.json
# TEST /content/data/results/15878300.json
# TEST /content/data/results/15626076.json
# TEST /content/data/results/15746975.json
# TEST /content/data/results/14405309.json
# TEST /content/data/results/16138373.json
# TEST /content/data/results/16031362.json
# TEST /content/data/results/16137787.json
# TEST /content/data/results/16146409.json
# TEST /content/data/results/15870132.json
# TEST /content/data/results/15297336.json
# TEST /content/data/results/16009724.json
# TEST /content/data/results/15870149.json
# TEST /content/data/results/15577596.json
# TEST /content/data/results/16151600.json
# TEST /content/data/results/15621819.json
# TEST /content/data/results/15747035.json
# TEST /content/data/results/16037850.json
# TEST /content/data/results/16013559.json
# TEST /content/data/results/16036968.json
# TEST /content/data/results/15436619.json
# TEST /content/data/results/15569303.json
# TEST /content/data/results/15877424.json
# TEST /content/data/results/14439886.json
# TEST /content/data/results/16060903.json
# TEST /content/data/results/16134122.json
# TEST /content/data/results/15433928.json
# TEST /content/data/results/16037867.json
# TEST /content/data/results/16127139.json
# TEST /content/data/results/15620435.json
# TEST /content/data/results/16013565.json
# TEST /content/data/results/15872243.json
# TEST /content/data/results/14063843.json
# TEST /content/data/results/16013536.json
# TEST /content/data/results/15253072.json
# TEST /content/data/results/15816138.json
# TEST /content/data/results/15877944.json
# TEST /content/data/results/16029951.json
# TEST /content/data/results/14239957.json
# TEST /content/data/results/16036939.json
# TEST /content/data/results/15417272.json
# TEST /content/data/results/15782698.json
# TEST /content/data/results/16037873.json
# TEST /content/data/results/15660802.json
# TEST /content/data/results/15815104.json
# TEST /content/data/results/14291188.json
# TEST /content/data/results/16013507.json
# TEST /content/data/results/15870161.json
# TEST /content/data/results/15735032.json
# TEST /content/data/results/15877418.json
# TEST /content/data/results/15584573.json
# TEST /content/data/results/15637128.json
# TEST /content/data/results/16037896.json
# TEST /content/data/results/16013588.json
# TEST /content/data/results/15620441.json
# TEST /content/data/results/16127145.json
# TEST /content/data/results/14405284.json
# TEST /content/data/results/15583929.json
# TEST /content/data/results/16127211.json
# TEST /content/data/results/15747041.json
# TEST /content/data/results/15569438.json
# TEST /content/data/results/15568261.json
# TEST /content/data/results/16127151.json
# TEST /content/data/results/10822387.json
# TEST /content/data/results/16013542.json
# TEST /content/data/results/16146390.json
# TEST /content/data/results/15870126.json
# TEST /content/data/results/15577567.json
# TEST /content/data/results/15612594.json
# TEST /content/data/results/14026977.json
# TEST /content/data/results/15433934.json
# TEST /content/data/results/14324120.json
# TEST /content/data/results/15634182.json
# TEST /content/data/results/14257607.json
# TEST /content/data/results/15993685.json
# TEST /content/data/results/15297313.json
# TEST /content/data/results/15587896.json
# TEST /content/data/results/15817681.json
# TEST /content/data/results/16060895.json
# TEST /content/data/results/15417295.json
# TEST /content/data/results/16127257.json
# TEST /content/data/results/16023138.json
# TEST /content/data/results/15866432.json
# TEST /content/data/results/15861736.json
# TEST /content/data/results/16082431.json
# TEST /content/data/results/15861417.json
# TEST /content/data/results/15861802.json
# TEST /content/data/results/15570737.json
# TEST /content/data/results/15881561.json
# TEST /content/data/results/15572133.json
# TEST /content/data/results/15747029.json
# TEST /content/data/results/15370837.json
# TEST /content/data/results/15821429.json
# TEST /content/data/results/16202183.json
# ERROR for PZN 16202183: missing EDQM info. Package: `Aseptoman Parfümfrei Händedesinfektion 150 ml`. Mapping: `nan`. MMI: `Lösung`.
# TEST /content/data/results/16085174.json
# TEST /content/data/results/15861860.json
# TEST /content/data/results/15889396.json
# TEST /content/data/results/15746998.json
# TEST /content/data/results/15432567.json
# TEST /content/data/results/15572156.json
# TEST /content/data/results/16085168.json
# TEST /content/data/results/16134091.json
# TEST /content/data/results/15370872.json
# TEST /content/data/results/15866449.json
# TEST /content/data/results/6115365.json
# TEST /content/data/results/16085151.json
# TEST /content/data/results/15815185.json
# TEST /content/data/results/15782907.json
# TEST /content/data/results/15861908.json
# TEST /content/data/results/16134085.json
# TEST /content/data/results/15238871.json
# TEST /content/data/results/15861914.json
# TEST /content/data/results/15747012.json
# TEST /content/data/results/15024348.json
# TEST /content/data/results/15570708.json
# TEST /content/data/results/15823279.json
# TEST /content/data/results/15570743.json
# TEST /content/data/results/15861819.json
# TEST /content/data/results/16085056.json
# TEST /content/data/results/15370843.json
# TEST /content/data/results/15861854.json
# TEST /content/data/results/16201143.json
# TEST /content/data/results/16060151.json
# TEST /content/data/results/15530933.json
# TEST /content/data/results/15370814.json
# TEST /content/data/results/16037146.json
# TEST /content/data/results/16123986.json
# TEST /content/data/results/14375146.json
# TEST /content/data/results/15370820.json
# TEST /content/data/results/15370889.json
# TEST /content/data/results/14039052.json
# TEST /content/data/results/15861759.json
# TEST /content/data/results/15745208.json
# TEST /content/data/results/15560578.json
# TEST /content/data/results/15609907.json
# TEST /content/data/results/14170562.json
# TEST /content/data/results/15861742.json
# TEST /content/data/results/16147136.json
# TEST /content/data/results/15370866.json
# TEST /content/data/results/15866426.json
# TEST /content/data/results/15881609.json
# TEST /content/data/results/16123963.json
# TEST /content/data/results/16201166.json
# TEST /content/data/results/15782178.json
# TEST /content/data/results/16123957.json
# TEST /content/data/results/15996519.json
# TEST /content/data/results/16134139.json
# TEST /content/data/results/16082448.json
# TEST /content/data/results/16123940.json
# TEST /content/data/results/15896769.json
# TEST /content/data/results/14320487.json
# TEST /content/data/results/14320493.json
# TEST /content/data/results/16023167.json
# TEST /content/data/results/15824830.json
# TEST /content/data/results/15297632.json
# TEST /content/data/results/11323700.json
# TEST /content/data/results/12550332.json
# TEST /content/data/results/16224931.json
# TEST /content/data/results/11708771.json
# TEST /content/data/results/15735687.json
# TEST /content/data/results/16231090.json
# TEST /content/data/results/15437151.json
# TEST /content/data/results/16230498.json
# TEST /content/data/results/15745728.json
# TEST /content/data/results/13985061.json
# TEST /content/data/results/15824959.json
# TEST /content/data/results/16224977.json
# TEST /content/data/results/15824847.json
# TEST /content/data/results/16003242.json
# TEST /content/data/results/12548619.json
# TEST /content/data/results/15786590.json
# TEST /content/data/results/15865208.json
# TEST /content/data/results/16020938.json
# TEST /content/data/results/15865303.json
# TEST /content/data/results/16224948.json
# TEST /content/data/results/15865332.json
# TEST /content/data/results/16003265.json
# TEST /content/data/results/15861334.json
# TEST /content/data/results/15297661.json
# TEST /content/data/results/15607541.json
# TEST /content/data/results/16003236.json
# TEST /content/data/results/16023492.json
# TEST /content/data/results/15865384.json
# TEST /content/data/results/15865214.json
# TEST /content/data/results/16142512.json
# TEST /content/data/results/16142529.json
# TEST /content/data/results/15437168.json
# TEST /content/data/results/15297678.json
# TEST /content/data/results/15389647.json
# TEST /content/data/results/14417637.json
# TEST /content/data/results/15639297.json
# TEST /content/data/results/15824770.json
# TEST /content/data/results/11323137.json
# TEST /content/data/results/14359495.json
# TEST /content/data/results/15562991.json
# TEST /content/data/results/16230251.json
# TEST /content/data/results/15866159.json
# TEST /content/data/results/15437079.json
# TEST /content/data/results/16120870.json
# TEST /content/data/results/15865160.json
# TEST /content/data/results/15895652.json
# TEST /content/data/results/16003259.json
# TEST /content/data/results/16230222.json
# TEST /content/data/results/15824942.json
# TEST /content/data/results/16000700.json
# TEST /content/data/results/16120864.json
# TEST /content/data/results/13913162.json
# TEST /content/data/results/16231049.json
# TEST /content/data/results/16021151.json
# TEST /content/data/results/16231279.json
# TEST /content/data/results/16203024.json
# TEST /content/data/results/11323663.json
# TEST /content/data/results/16224954.json
# TEST /content/data/results/15875170.json
# TEST /content/data/results/14417206.json
# TEST /content/data/results/15865119.json
# TEST /content/data/results/15530910.json
# TEST /content/data/results/16230239.json
# TEST /content/data/results/15865131.json
# TEST /content/data/results/11323746.json
# TEST /content/data/results/12501279.json
# TEST /content/data/results/15437122.json
# TEST /content/data/results/11706424.json
# TEST /content/data/results/16224983.json
# TEST /content/data/results/14359213.json
# TEST /content/data/results/15437145.json
# TEST /content/data/results/16231262.json
# TEST /content/data/results/15437062.json
# TEST /content/data/results/15437116.json
# TEST /content/data/results/16011193.json
# TEST /content/data/results/16224894.json
# TEST /content/data/results/15865349.json
# TEST /content/data/results/15865266.json
# TEST /content/data/results/15865125.json
# TEST /content/data/results/15613168.json
# TEST /content/data/results/15782149.json
# TEST /content/data/results/15198350.json
# TEST /content/data/results/15820737.json
# TEST /content/data/results/14033291.json
# TEST /content/data/results/16231167.json
# TEST /content/data/results/15866142.json
# TEST /content/data/results/16229957.json
# TEST /content/data/results/12548542.json
# TEST /content/data/results/11705181.json
# TEST /content/data/results/14359503.json
# TEST /content/data/results/16231204.json
# TEST /content/data/results/16203018.json
# TEST /content/data/results/16231285.json
# TEST /content/data/results/15437085.json
# TEST /content/data/results/16231144.json
# TEST /content/data/results/15639305.json
# TEST /content/data/results/15865272.json
# TEST /content/data/results/13515651.json
# TEST /content/data/results/15861386.json
# TEST /content/data/results/15824907.json
# TEST /content/data/results/15530927.json
# TEST /content/data/results/15865326.json
# TEST /content/data/results/16003207.json
# TEST /content/data/results/12501948.json
# TEST /content/data/results/16230512.json
# TEST /content/data/results/15786644.json
# TEST /content/data/results/15619745.json
# TEST /content/data/results/16120887.json
# TEST /content/data/results/16121177.json
# TEST /content/data/results/15297626.json
# TEST /content/data/results/16003182.json
# TEST /content/data/results/15297603.json
# TEST /content/data/results/15529545.json
# TEST /content/data/results/15889373.json
# TEST /content/data/results/16231032.json
# TEST /content/data/results/16003288.json
# TEST /content/data/results/11323634.json
# TEST /content/data/results/12550349.json
# TEST /content/data/results/16230506.json
# TEST /content/data/results/11704141.json
# TEST /content/data/results/15865295.json
# TEST /content/data/results/16163750.json
# TEST /content/data/results/15609161.json
# TEST /content/data/results/12893405.json
# TEST /content/data/results/15865177.json
# TEST /content/data/results/15613180.json
# TEST /content/data/results/16023782.json
# TEST /content/data/results/15999624.json
# TEST /content/data/results/14294583.json
# TEST /content/data/results/16003271.json
# TEST /content/data/results/16231084.json
# TEST /content/data/results/16003199.json
# TEST /content/data/results/15746969.json
# TEST /content/data/results/15815191.json
# TEST /content/data/results/16231233.json
# TEST /content/data/results/16231055.json
# TEST /content/data/results/15745734.json
# TEST /content/data/results/15865220.json
# TEST /content/data/results/16231227.json
# TEST /content/data/results/16231003.json
# TEST /content/data/results/15824965.json
# TEST /content/data/results/15577171.json
# TEST /content/data/results/16013996.json
# TEST /content/data/results/12548559.json
# TEST /content/data/results/11323640.json
# TEST /content/data/results/15816664.json
# TEST /content/data/results/16139266.json
# TEST /content/data/results/16231109.json
# TEST /content/data/results/16231196.json
# TEST /content/data/results/16231173.json
# TEST /content/data/results/11323166.json
# TEST /content/data/results/16230995.json
# TEST /content/data/results/10744776.json
# TEST /content/data/results/15865094.json
# TEST /content/data/results/15629637.json
# TEST /content/data/results/15629614.json
# TEST /content/data/results/16003213.json
# TEST /content/data/results/14359472.json
# TEST /content/data/results/16231256.json
# TEST /content/data/results/15865102.json
# TEST /content/data/results/14212651.json
# TEST /content/data/results/16121208.json
# TEST /content/data/results/16000717.json
# TEST /content/data/results/15609155.json
# TEST /content/data/results/15865361.json
# TEST /content/data/results/15639280.json
# TEST /content/data/results/11323717.json
# TEST /content/data/results/16231291.json
# TEST /content/data/results/14349025.json
# TEST /content/data/results/15613174.json
# TEST /content/data/results/15824876.json
# TEST /content/data/results/15420593.json
# TEST /content/data/results/15865154.json
# TEST /content/data/results/15865355.json
# TEST /content/data/results/16224960.json
# TEST /content/data/results/12548602.json
# TEST /content/data/results/16142506.json
# TEST /content/data/results/11323657.json
# TEST /content/data/results/15297690.json
# TEST /content/data/results/15660860.json
# TEST /content/data/results/16231026.json
# TEST /content/data/results/11705146.json
# TEST /content/data/results/15865378.json
# TEST /content/data/results/15861328.json
# TEST /content/data/results/11323628.json
# TEST /content/data/results/11323172.json
# TEST /content/data/results/15437091.json
# TEST /content/data/results/15865088.json
# TEST /content/data/results/16230481.json
# TEST /content/data/results/15786615.json
# TEST /content/data/results/11708966.json
# TEST /content/data/results/16230245.json
# TEST /content/data/results/15865237.json
# TEST /content/data/results/11323692.json
# TEST /content/data/results/15297684.json
# TEST /content/data/results/15437139.json
# TEST /content/data/results/16231150.json
# TEST /content/data/results/15824913.json
# TEST /content/data/results/15634940.json
# TEST /content/data/results/15865183.json
# TEST /content/data/results/15865409.json
# TEST /content/data/results/13913156.json
# TEST /content/data/results/16121289.json
# TEST /content/data/results/15197735.json
# TEST /content/data/results/15634213.json
# TEST /content/data/results/15865289.json
# TEST /content/data/results/15786472.json
# TEST /content/data/results/16231210.json
# TEST /content/data/results/11707984.json
# TEST /content/data/results/15824787.json
# TEST /content/data/results/15297649.json
# TEST /content/data/results/15629620.json
# TEST /content/data/results/15865148.json
# TEST /content/data/results/16224925.json
# TEST /content/data/results/11853616.json
# TEST /content/data/results/15785283.json
# TEST /content/data/results/15784361.json
# TEST /content/data/results/15784409.json
# TEST /content/data/results/15885636.json
# TEST /content/data/results/16035940.json
# TEST /content/data/results/15996666.json
# TEST /content/data/results/15639133.json
# TEST /content/data/results/15784496.json
# TEST /content/data/results/15895942.json
# TEST /content/data/results/15264420.json
# TEST /content/data/results/15264414.json
# TEST /content/data/results/15894859.json
# TEST /content/data/results/12353666.json
# TEST /content/data/results/15884341.json
# TEST /content/data/results/15264578.json
# TEST /content/data/results/15784467.json
# TEST /content/data/results/16201686.json
# TEST /content/data/results/15433420.json
# TEST /content/data/results/15816486.json
# TEST /content/data/results/15784504.json
# TEST /content/data/results/15994644.json
# TEST /content/data/results/15884358.json
# TEST /content/data/results/13714528.json
# TEST /content/data/results/16135908.json
# TEST /content/data/results/15241206.json
# TEST /content/data/results/16134062.json
# TEST /content/data/results/16009693.json
# TEST /content/data/results/16037100.json
# TEST /content/data/results/15784355.json
# TEST /content/data/results/15881590.json
# TEST /content/data/results/16006128.json
# TEST /content/data/results/15894799.json
# TEST /content/data/results/16018485.json
# TEST /content/data/results/14438786.json
# TEST /content/data/results/15620027.json
# TEST /content/data/results/16038743.json
# TEST /content/data/results/16201692.json
# TEST /content/data/results/16037117.json
# TEST /content/data/results/15885642.json
# TEST /content/data/results/15568344.json
# TEST /content/data/results/16018462.json
# TEST /content/data/results/15817706.json
# TEST /content/data/results/15582858.json
# TEST /content/data/results/16196577.json
# TEST /content/data/results/15878004.json
# TEST /content/data/results/16037123.json
# TEST /content/data/results/16169712.json
# TEST /content/data/results/15198781.json
# TEST /content/data/results/15460724.json
# TEST /content/data/results/15822771.json
# TEST /content/data/results/16037086.json
# TEST /content/data/results/15784390.json
# TEST /content/data/results/15264561.json
# TEST /content/data/results/16140938.json
# TEST /content/data/results/16037092.json
# TEST /content/data/results/15822707.json
# TEST /content/data/results/13423110.json
# TEST /content/data/results/15894807.json
# TEST /content/data/results/15822788.json
# TEST /content/data/results/16124253.json
# TEST /content/data/results/15264443.json
# TEST /content/data/results/16129084.json
# TEST /content/data/results/15264615.json
# TEST /content/data/results/15264609.json
# TEST /content/data/results/15894782.json
# TEST /content/data/results/15784562.json
# TEST /content/data/results/15894776.json
# TEST /content/data/results/15264644.json
# TEST /content/data/results/15300104.json
# TEST /content/data/results/15882543.json
# TEST /content/data/results/15237185.json
# TEST /content/data/results/16037057.json
# TEST /content/data/results/15786638.json
# TEST /content/data/results/15897177.json
# TEST /content/data/results/16169706.json
# TEST /content/data/results/11706039.json
# TEST /content/data/results/16085122.json
# TEST /content/data/results/16010992.json
# TEST /content/data/results/16133944.json
# TEST /content/data/results/15264472.json
# TEST /content/data/results/16136026.json
# TEST /content/data/results/16135297.json
# TEST /content/data/results/15784332.json
# TEST /content/data/results/15620062.json
# TEST /content/data/results/15784556.json
# TEST /content/data/results/15746886.json
# TEST /content/data/results/15264549.json
# TEST /content/data/results/16169735.json
# TEST /content/data/results/15784527.json
# TEST /content/data/results/12855008.json
# TEST /content/data/results/15434017.json
# TEST /content/data/results/15433414.json
# TEST /content/data/results/15264331.json
# TEST /content/data/results/15433874.json
# TEST /content/data/results/15432171.json
# TEST /content/data/results/16085116.json
# TEST /content/data/results/15822713.json
# TEST /content/data/results/16124276.json
# TEST /content/data/results/15250607.json
# TEST /content/data/results/16260631.json
# TEST /content/data/results/16011000.json
# TEST /content/data/results/15894813.json
# TEST /content/data/results/16037040.json
# TEST /content/data/results/15264673.json
# TEST /content/data/results/15881584.json
# TEST /content/data/results/16037063.json
# TEST /content/data/results/15460730.json
# TEST /content/data/results/16206270.json
# TEST /content/data/results/15861647.json
# TEST /content/data/results/15617479.json
# TEST /content/data/results/16085079.json
# TEST /content/data/results/15785805.json
# TEST /content/data/results/15433880.json
# TEST /content/data/results/15639162.json
# TEST /content/data/results/15237191.json
# TEST /content/data/results/14160894.json
# TEST /content/data/results/16235194.json
# TEST /content/data/results/15784303.json
# TEST /content/data/results/14309965.json
# TEST /content/data/results/16160409.json
# TEST /content/data/results/16134116.json
# TEST /content/data/results/16021168.json
# TEST /content/data/results/15568367.json
# TEST /content/data/results/15784533.json
# TEST /content/data/results/15885613.json
# TEST /content/data/results/16152887.json
# TEST /content/data/results/15816196.json
# TEST /content/data/results/15822736.json
# TEST /content/data/results/15460718.json
# TEST /content/data/results/15639156.json
# TEST /content/data/results/15822848.json
# TEST /content/data/results/16169729.json
# TEST /content/data/results/15639216.json
# TEST /content/data/results/16007470.json
# TEST /content/data/results/15894842.json
# TEST /content/data/results/15822831.json
# TEST /content/data/results/15617456.json
# TEST /content/data/results/15890011.json
# TEST /content/data/results/15434069.json
# TEST /content/data/results/15735701.json
# TEST /content/data/results/13423050.json
# TEST /content/data/results/15822742.json
# TEST /content/data/results/15264621.json
# TEST /content/data/results/15784415.json
# TEST /content/data/results/14330818.json
# TEST /content/data/results/15433905.json
# TEST /content/data/results/15816457.json
# TEST /content/data/results/15639185.json
# TEST /content/data/results/16085085.json
# TEST /content/data/results/15264408.json
# TEST /content/data/results/16124282.json
# TEST /content/data/results/16244833.json
# TEST /content/data/results/15784295.json
# TEST /content/data/results/15822794.json
# TEST /content/data/results/12893397.json
# TEST /content/data/results/15569378.json
# TEST /content/data/results/15786495.json
# TEST /content/data/results/15784326.json
# TEST /content/data/results/15299973.json
# TEST /content/data/results/16196560.json
# TEST /content/data/results/15264532.json
# TEST /content/data/results/14308776.json
# TEST /content/data/results/15264377.json
# TEST /content/data/results/15264325.json
# TEST /content/data/results/15864491.json
# TEST /content/data/results/15784450.json
# TEST /content/data/results/15816463.json
# TEST /content/data/results/15619768.json
# TEST /content/data/results/15784349.json
# TEST /content/data/results/15894836.json
# TEST /content/data/results/15822699.json
# TEST /content/data/results/15880202.json
# TEST /content/data/results/15264360.json
# TEST /content/data/results/15264650.json
# TEST /content/data/results/15264319.json
# TEST /content/data/results/15786443.json
# TEST /content/data/results/15822759.json
# TEST /content/data/results/16085139.json
# TEST /content/data/results/16134056.json
# TEST /content/data/results/15264354.json
# TEST /content/data/results/15822825.json
# TEST /content/data/results/16231316.json
# TEST /content/data/results/15639179.json
# TEST /content/data/results/16037152.json
# TEST /content/data/results/15264526.json
# TEST /content/data/results/15864485.json
# TEST /content/data/results/15639191.json
# TEST /content/data/results/16137089.json
# TEST /content/data/results/16085062.json
# TEST /content/data/results/16160384.json
# TEST /content/data/results/15433897.json
# TEST /content/data/results/15434046.json
# TEST /content/data/results/16031818.json
# TEST /content/data/results/15301718.json
# TEST /content/data/results/16010957.json
# TEST /content/data/results/15878010.json
# TEST /content/data/results/15568321.json
# TEST /content/data/results/15264489.json
# TEST /content/data/results/16010986.json
# TEST /content/data/results/11705198.json
# TEST /content/data/results/15434023.json
# TEST /content/data/results/14055163.json
# TEST /content/data/results/16016954.json
# TEST /content/data/results/14308782.json
# TEST /content/data/results/15884364.json
# TEST /content/data/results/15264584.json
# TEST /content/data/results/16322148.json
# TEST /content/data/results/16322131.json
# TEST /content/data/results/16322125.json
# TEST /content/data/results/13359180.json
# TEST /content/data/results/16241740.json
# ERROR for PZN 16241740: missing EDQM info. Package: `Acidum benzoicum e resina LM 24 Arcana Dilution 10ml N1`. Mapping: `nan`. MMI: `Dil.`.
# TEST /content/data/results/13878218.json
# TEST /content/data/results/16017876.json
# TEST /content/data/results/15387269.json
# TEST /content/data/results/16319531.json
# TEST /content/data/results/16023486.json
# TEST /content/data/results/16328702.json
# TEST /content/data/results/16241786.json
# ERROR for PZN 16241786: missing EDQM info. Package: `Acidum benzoicum e resina LM 26 Arcana Dilution 10ml N1`. Mapping: `nan`. MMI: `Dil.`.
# TEST /content/data/results/15387252.json
# TEST /content/data/results/16202071.json
# TEST /content/data/results/14214992.json
# TEST /content/data/results/15739863.json
# TEST /content/data/results/15387246.json
# TEST /content/data/results/16319347.json
# TEST /content/data/results/15895830.json
# TEST /content/data/results/16241898.json
# ERROR for PZN 16241898: missing EDQM info. Package: `Acidum benzoicum e resina LM 75 Arcana Dilution 10ml N1`. Mapping: `nan`. MMI: `Dil.`.
# TEST /content/data/results/15820861.json
# TEST /content/data/results/16144824.json
# TEST /content/data/results/15387217.json
# TEST /content/data/results/16201485.json
# TEST /content/data/results/16320698.json
# TEST /content/data/results/16164028.json
# TEST /content/data/results/11708400.json
# TEST /content/data/results/15895801.json
# TEST /content/data/results/16203685.json
# TEST /content/data/results/16320652.json
# TEST /content/data/results/15660883.json
# TEST /content/data/results/16023463.json
# TEST /content/data/results/15744143.json
# TEST /content/data/results/15814984.json
# TEST /content/data/results/15861392.json
# TEST /content/data/results/16124359.json
# TEST /content/data/results/16218936.json
# TEST /content/data/results/15820915.json
# TEST /content/data/results/16198458.json
# TEST /content/data/results/16123934.json
# TEST /content/data/results/15816173.json
# TEST /content/data/results/7711514.json
# TEST /content/data/results/15739969.json
# TEST /content/data/results/16241869.json
# ERROR for PZN 16241869: missing EDQM info. Package: `Acidum benzoicum e resina LM 36 Arcana Dilution 10ml N1`. Mapping: `nan`. MMI: `Dil.`.
# TEST /content/data/results/16320764.json
# TEST /content/data/results/14001894.json
# TEST /content/data/results/16241881.json
# ERROR for PZN 16241881: missing EDQM info. Package: `Acidum benzoicum e resina LM 60 Arcana Dilution 10ml N1`. Mapping: `nan`. MMI: `Dil.`.
# TEST /content/data/results/15744120.json
# TEST /content/data/results/16007441.json
# TEST /content/data/results/12443889.json
# TEST /content/data/results/16241591.json
# ERROR for PZN 16241591: missing EDQM info. Package: `Acidum benzoicum e resina LM 10 Arcana Dilution 10ml N1`. Mapping: `nan`. MMI: `Dil.`.
# TEST /content/data/results/14356775.json
# TEST /content/data/results/13359197.json
# TEST /content/data/results/13982648.json
# TEST /content/data/results/16023457.json
# TEST /content/data/results/16241912.json
# ERROR for PZN 16241912: missing EDQM info. Package: `Acidum benzoicum e resina LM 100 Arcana Dilution 10ml N1`. Mapping: `nan`. MMI: `Dil.`.
# TEST /content/data/results/15816055.json
# TEST /content/data/results/15303640.json
# TEST /content/data/results/14465211.json
# TEST /content/data/results/15576711.json
# TEST /content/data/results/15387192.json
# TEST /content/data/results/16086452.json
# TEST /content/data/results/16320480.json
# TEST /content/data/results/16023411.json
# TEST /content/data/results/16133950.json
# TEST /content/data/results/16003377.json
# TEST /content/data/results/15744137.json
# TEST /content/data/results/16002662.json
# TEST /content/data/results/16241935.json
# ERROR for PZN 16241935: missing EDQM info. Package: `Acidum benzoicum e resina LM 120 Arcana Dilution 10ml N1`. Mapping: `nan`. MMI: `Dil.`.
# TEST /content/data/results/15820878.json
# TEST /content/data/results/11707719.json
# TEST /content/data/results/16198493.json
# TEST /content/data/results/15529195.json
# TEST /content/data/results/11705637.json
# TEST /content/data/results/15630089.json
# TEST /content/data/results/16119364.json
# TEST /content/data/results/16170158.json
# TEST /content/data/results/14446018.json
# TEST /content/data/results/14288861.json
# TEST /content/data/results/16135883.json
# TEST /content/data/results/14465257.json
# TEST /content/data/results/16164011.json
# TEST /content/data/results/13878247.json
# TEST /content/data/results/15576674.json
# TEST /content/data/results/15816032.json
# TEST /content/data/results/16241645.json
# ...
# TEST /content/data/results/16780885.json
# TEST /content/data/results/16688151.json
# TEST /content/data/results/16166990.json
# TEST /content/data/results/16695464.json
# TEST /content/data/results/16688814.json
# TEST /content/data/results/16244862.json
# TEST /content/data/results/16688323.json
# TEST /content/data/results/16688435.json
# TEST /content/data/results/16688748.json
# TEST /content/data/results/16688180.json
# TEST /content/data/results/16748410.json
# TEST /content/data/results/15745332.json
# TEST /content/data/results/16398602.json
# TEST /content/data/results/16688702.json
# TEST /content/data/results/16780980.json
# TEST /content/data/results/16628456.json
# TEST /content/data/results/13878170.json
# TEST /content/data/results/16688613.json
# TEST /content/data/results/16701176.json
# TEST /content/data/results/16741448.json
# TEST /content/data/results/16696920.json
# TEST /content/data/results/15563536.json
# TEST /content/data/results/16688381.json
# TEST /content/data/results/16688961.json
# TEST /content/data/results/16738274.json
# TEST /content/data/results/16684615.json
# TEST /content/data/results/16688932.json
# TEST /content/data/results/16229963.json
# TEST /content/data/results/16780945.json
# TEST /content/data/results/16200209.json
# TEST /content/data/results/16688493.json
# TEST /content/data/results/16398370.json
# TEST /content/data/results/16628479.json
# TEST /content/data/results/16688688.json
# TEST /content/data/results/15416427.json
# TEST /content/data/results/16695671.json
# TEST /content/data/results/16616921.json
# TEST /content/data/results/16680422.json
# TEST /content/data/results/13816654.json
# TEST /content/data/results/13816714.json
# TEST /content/data/results/16688843.json
# TEST /content/data/results/15563588.json
# TEST /content/data/results/16694967.json
# TEST /content/data/results/16605277.json
# TEST /content/data/results/16385574.json
# TEST /content/data/results/14329985.json
# TEST /content/data/results/16569512.json
# TEST /content/data/results/13834899.json
# TEST /content/data/results/15416485.json
# TEST /content/data/results/16688145.json
# TEST /content/data/results/16511079.json
# TEST /content/data/results/16086328.json
# TEST /content/data/results/16163595.json
# TEST /content/data/results/16695010.json
# TEST /content/data/results/16688257.json
# TEST /content/data/results/16693092.json
# ERROR for PZN 16693092: missing EDQM info. Package: `Petroleum rectificatum C12 DHU Dilution 20ml N1`. Mapping: `nan`. MMI: `Dil.`.
# TEST /content/data/results/16689297.json
# TEST /content/data/results/16689280.json
# TEST /content/data/results/16687306.json
# TEST /content/data/results/16695062.json
# TEST /content/data/results/16689127.json
# TEST /content/data/results/16689162.json
# TEST /content/data/results/13834907.json
# TEST /content/data/results/15373244.json
# TEST /content/data/results/16687565.json
# TEST /content/data/results/16688760.json
# TEST /content/data/results/16569498.json
# TEST /content/data/results/16688547.json
# TEST /content/data/results/16695613.json
# TEST /content/data/results/16086305.json
# TEST /content/data/results/16688524.json
# TEST /content/data/results/16689038.json
# TEST /content/data/results/16695487.json
# TEST /content/data/results/16533804.json
# TEST /content/data/results/16037689.json
# TEST /content/data/results/16605202.json
# TEST /content/data/results/16694950.json
# TEST /content/data/results/16689392.json
# TEST /content/data/results/16575903.json
# TEST /content/data/results/16763438.json
# TEST /content/data/results/15569243.json
# TEST /content/data/results/16632914.json
# TEST /content/data/results/16737286.json
# TEST /content/data/results/16695079.json
# TEST /content/data/results/16792581.json
# TEST /content/data/results/16688694.json
# TEST /content/data/results/16700998.json
# TEST /content/data/results/16144882.json
# TEST /content/data/results/16505156.json
# TEST /content/data/results/14329991.json
# TEST /content/data/results/16696558.json
# ERROR for PZN 16696558: missing EDQM info. Package: `Serum anguillae D6 DHU 50ml Dil. N1`. Mapping: `nan`. MMI: `Dil.`.
# TEST /content/data/results/16689104.json
# TEST /content/data/results/16688949.json
# TEST /content/data/results/16695406.json
# TEST /content/data/results/15563476.json
# TEST /content/data/results/16533810.json
# TEST /content/data/results/16200304.json
# TEST /content/data/results/16689073.json
# TEST /content/data/results/16695636.json
# TEST /content/data/results/16696104.json
# TEST /content/data/results/16793907.json
# TEST /content/data/results/16695435.json
# TEST /content/data/results/15563631.json
# TEST /content/data/results/16689274.json
# TEST /content/data/results/15416491.json
# TEST /content/data/results/16689110.json
# TEST /content/data/results/16688820.json
# TEST /content/data/results/16695607.json
# TEST /content/data/results/16695116.json
# TEST /content/data/results/15568485.json
# TEST /content/data/results/16688168.json
# TEST /content/data/results/16780856.json
# TEST /content/data/results/15569266.json
# TEST /content/data/results/16633078.json
# TEST /content/data/results/16769895.json
# TEST /content/data/results/16695582.json
# TEST /content/data/results/16780997.json
# TEST /content/data/results/16693436.json
# ERROR for PZN 16693436: missing EDQM info. Package: `Quercus e glandibus D3 DHU Dilution 50ml N1`. Mapping: `nan`. MMI: `Dil.`.
# TEST /content/data/results/16694973.json
# TEST /content/data/results/16749409.json
# TEST /content/data/results/16695004.json
# TEST /content/data/results/16689179.json
# TEST /content/data/results/16688530.json
# TEST /content/data/results/16737263.json
# TEST /content/data/results/16695033.json
# TEST /content/data/results/15660877.json
# TEST /content/data/results/16695553.json
# TEST /content/data/results/16200215.json
# TEST /content/data/results/16797561.json
# TEST /content/data/results/10167379.json
# TEST /content/data/results/16700917.json
# TEST /content/data/results/16020944.json
# TEST /content/data/results/16696386.json
# TEST /content/data/results/16688139.json
# TEST /content/data/results/16797578.json
# TEST /content/data/results/13834942.json
# TEST /content/data/results/16688458.json
# TEST /content/data/results/16000611.json
# TEST /content/data/results/16702796.json
# TEST /content/data/results/16780879.json
# TEST /content/data/results/16690337.json
# ERROR for PZN 16690337: missing EDQM info. Package: `Codeinum phosphoricum D6 DHU Dilution 50ml N1`. Mapping: `nan`. MMI: `Dil.`.
# TEST /content/data/results/16689067.json
# TEST /content/data/results/16688375.json
# TEST /content/data/results/16688719.json
# TEST /content/data/results/16691437.json
# ERROR for PZN 16691437: missing EDQM info. Package: `Gutti D6 DHU Dilution 20ml N1`. Mapping: `nan`. MMI: `Dil.`.
# TEST /content/data/results/14299244.json
# TEST /content/data/results/16609602.json
# TEST /content/data/results/16688518.json
# TEST /content/data/results/16749415.json
# TEST /content/data/results/16699025.json
# TEST /content/data/results/16695441.json
# TEST /content/data/results/16703979.json
# TEST /content/data/results/16689311.json
# TEST /content/data/results/16689363.json
# TEST /content/data/results/16259987.json
# TEST /content/data/results/16688369.json
# TEST /content/data/results/16780827.json
# TEST /content/data/results/16569506.json
# TEST /content/data/results/16688205.json
# TEST /content/data/results/16695493.json
# TEST /content/data/results/15563401.json
# TEST /content/data/results/13834988.json
# TEST /content/data/results/16689044.json
# TEST /content/data/results/16695205.json
# ERROR for PZN 16695205: missing EDQM info. Package: `Ginkgo biloba D30 DHU Dilution 50ml N1`. Mapping: `nan`. MMI: `Dil.`.
# TEST /content/data/results/16759603.json
# TEST /content/data/results/16689050.json
# TEST /content/data/results/15569272.json
# TEST /content/data/results/16530674.json
# TEST /content/data/results/16780916.json
# TEST /content/data/results/15373238.json
# TEST /content/data/results/16688754.json
# TEST /content/data/results/16632877.json
# TEST /content/data/results/16679471.json
# TEST /content/data/results/16695501.json
# TEST /content/data/results/16688464.json
# TEST /content/data/results/16689021.json
# TEST /content/data/results/16780833.json
# TEST /content/data/results/16398677.json
# TEST /content/data/results/16688955.json
# TEST /content/data/results/13834994.json
# TEST /content/data/results/16688300.json
# TEST /content/data/results/16688174.json
# TEST /content/data/results/16692974.json
# ERROR for PZN 16692974: missing EDQM info. Package: `Paloondo D6 DHU Dilution 20ml N1`. Mapping: `nan`. MMI: `Dil.`.
# TEST /content/data/results/16689216.json
# TEST /content/data/results/16695352.json
# ERROR for PZN 16695352: missing EDQM info. Package: `Thuja C30 DHU 50ml Dil. N1`. Mapping: `nan`. MMI: `Dil.`.
# TEST /content/data/results/16688659.json
# TEST /content/data/results/16689185.json
# TEST /content/data/results/15563447.json
# TEST /content/data/results/16568234.json
# TEST /content/data/results/16688197.json
# TEST /content/data/results/16160510.json
# TEST /content/data/results/16688412.json
# TEST /content/data/results/16689156.json
# TEST /content/data/results/16738216.json
# TEST /content/data/results/15862871.json
# TEST /content/data/results/16737352.json
# TEST /content/data/results/16771722.json
# TEST /content/data/results/12501902.json
# TEST /content/data/results/15616729.json
# TEST /content/data/results/16684590.json
# TEST /content/data/results/16687849.json
# TEST /content/data/results/16385048.json
# INFO  for PZN 16385048: no ATC code – skipping..
# TEST /content/data/results/16779882.json
# TEST /content/data/results/16735152.json
# TEST /content/data/results/16737346.json
# TEST /content/data/results/16653477.json
# TEST /content/data/results/16653520.json
# TEST /content/data/results/14166827.json
# TEST /content/data/results/16682881.json
# TEST /content/data/results/15877275.json
# TEST /content/data/results/16808359.json
# TEST /content/data/results/11710791.json
# TEST /content/data/results/16808750.json
# TEST /content/data/results/16384043.json
# TEST /content/data/results/16702804.json
# TEST /content/data/results/16679063.json
# TEST /content/data/results/13231310.json
# TEST /content/data/results/16682958.json
# TEST /content/data/results/16679040.json
# TEST /content/data/results/16682906.json
# TEST /content/data/results/13816619.json
# TEST /content/data/results/16399429.json
# INFO  for PZN 16399429: no ATC code – skipping..
# TEST /content/data/results/16225646.json
# TEST /content/data/results/16653514.json
# TEST /content/data/results/16575412.json
# TEST /content/data/results/16385031.json
# INFO  for PZN 16385031: no ATC code – skipping..
# TEST /content/data/results/16323679.json
# TEST /content/data/results/16331590.json
# TEST /content/data/results/16675444.json
# TEST /content/data/results/16517389.json
# TEST /content/data/results/16682935.json
# TEST /content/data/results/16719070.json
# TEST /content/data/results/16513813.json
# TEST /content/data/results/16575369.json
# TEST /content/data/results/16385077.json
# INFO  for PZN 16385077: no ATC code – skipping..
# TEST /content/data/results/16811924.json
# TEST /content/data/results/16315131.json
# TEST /content/data/results/16774790.json
# TEST /content/data/results/11710762.json
# TEST /content/data/results/16742850.json
# TEST /content/data/results/15616741.json
# TEST /content/data/results/16398708.json
# TEST /content/data/results/16509220.json
# TEST /content/data/results/16682970.json
# TEST /content/data/results/16660477.json
# TEST /content/data/results/16675415.json
# TEST /content/data/results/16783429.json
# TEST /content/data/results/16754037.json
# TEST /content/data/results/16732946.json
# TEST /content/data/results/16261398.json
# TEST /content/data/results/16682964.json
# TEST /content/data/results/16654577.json
# TEST /content/data/results/16654554.json
# TEST /content/data/results/16682929.json
# TEST /content/data/results/16749496.json
# TEST /content/data/results/16225652.json
# TEST /content/data/results/13816625.json
# TEST /content/data/results/16807868.json
# TEST /content/data/results/16682987.json
# TEST /content/data/results/16742867.json
# TEST /content/data/results/16810267.json
# TEST /content/data/results/11710779.json
# TEST /content/data/results/15997513.json
# TEST /content/data/results/16575346.json
# TEST /content/data/results/16624576.json
# TEST /content/data/results/16808767.json
# TEST /content/data/results/16675409.json
# TEST /content/data/results/16682898.json
# TEST /content/data/results/16144830.json
# TEST /content/data/results/16582062.json
# TEST /content/data/results/14290869.json
# TEST /content/data/results/15862842.json
# TEST /content/data/results/16397689.json
# TEST /content/data/results/16749964.json
# TEST /content/data/results/16741307.json
# TEST /content/data/results/15237216.json
# TEST /content/data/results/16687855.json
# TEST /content/data/results/16764277.json
# TEST /content/data/results/16809672.json
# TEST /content/data/results/15237133.json
# TEST /content/data/results/16565626.json
# TEST /content/data/results/16682875.json
# TEST /content/data/results/16768453.json
# TEST /content/data/results/16384020.json
# TEST /content/data/results/16320221.json
# TEST /content/data/results/11710845.json
# TEST /content/data/results/16654548.json
# TEST /content/data/results/16225669.json
# TEST /content/data/results/11710839.json
# TEST /content/data/results/16600305.json
# TEST /content/data/results/16575352.json
# TEST /content/data/results/16331609.json
# TEST /content/data/results/16659600.json
# TEST /content/data/results/16653483.json
# TEST /content/data/results/16755232.json
# TEST /content/data/results/16575381.json
# TEST /content/data/results/15862865.json
# TEST /content/data/results/16225681.json
# TEST /content/data/results/16397376.json
# INFO  for PZN 16397376: no ATC code – skipping..
# TEST /content/data/results/16575398.json
# TEST /content/data/results/16682912.json
# TEST /content/data/results/13816708.json
# TEST /content/data/results/16575375.json
# TEST /content/data/results/16199802.json
# TEST /content/data/results/16653508.json
# TEST /content/data/results/16679057.json
# TEST /content/data/results/16513807.json
# TEST /content/data/results/15616712.json
# TEST /content/data/results/16238525.json
# TEST /content/data/results/16757604.json
# TEST /content/data/results/16199794.json
# TEST /content/data/results/16768507.json
# TEST /content/data/results/16754422.json
# TEST /content/data/results/16624582.json
# TEST /content/data/results/16768074.json
# TEST /content/data/results/15237179.json
# TEST /content/data/results/15270490.json
# TEST /content/data/results/16779899.json
# TEST /content/data/results/16763154.json
# TEST /content/data/results/16809494.json
# TEST /content/data/results/16238531.json
# TEST /content/data/results/16654413.json
# TEST /content/data/results/16509237.json
# TEST /content/data/results/16687832.json
# TEST /content/data/results/15862859.json
# TEST /content/data/results/15616735.json
# TEST /content/data/results/16660460.json
# TEST /content/data/results/16624599.json
# TEST /content/data/results/16323550.json
# TEST /content/data/results/16225675.json
# TEST /content/data/results/16768619.json
# TEST /content/data/results/15997507.json
# TEST /content/data/results/11710822.json
# TEST /content/data/results/16261381.json
# TEST /content/data/results/16385083.json
# INFO  for PZN 16385083: no ATC code – skipping..
# TEST /content/data/results/16737323.json
# TEST /content/data/results/16783381.json
# TEST /content/data/results/16682941.json
# TEST /content/data/results/16146510.json
# TEST /content/data/results/16614460.json
# TEST /content/data/results/16575406.json
# TEST /content/data/results/16234214.json
# TEST /content/data/results/16200310.json
# TEST /content/data/results/16398737.json
# INFO  for PZN 16398737: no ATC code – skipping..
# TEST /content/data/results/11710785.json
# TEST /content/data/results/16225698.json
# TEST /content/data/results/11331013.json
# TEST /content/data/results/16385060.json
# INFO  for PZN 16385060: no ATC code – skipping..
# TEST /content/data/results/16684609.json
# TEST /content/data/results/14055039.json
# TEST /content/data/results/16260743.json
# TEST /content/data/results/16369569.json
# TEST /content/data/results/16732923.json
# TEST /content/data/results/11710816.json
# TEST /content/data/results/16749510.json
# TEST /content/data/results/16811640.json

# %%
# !zip -r "/content/data/output.zip" "/content/data/results"
